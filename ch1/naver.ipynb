# %%
# 선풍기, 청바지, 수영복, 신발, 여행
# 100 개 씩, 총 500 개 데이터 화면에 출력
# title, category1, category2, category3, lprice, brand

# %%
import requests
import re

# %%
import sqlite3
from datetime import datetime

conn = sqlite3.connect("./database/shop.db",isolation_level=None)
cursor = conn.cursor()
cursor.execute("CREATE TABLE IF NOT EXISTS myshop(no integer primary key, category1 text, category2 text, category3 text, brand text, title text, lprice integer, regdate text)")

# %%
keywords = ["선풍기", "청바지", "수영복", "신발", "여행"]
url = 'https://openapi.naver.com/v1/search/shop.json'
headers = {
    "X-Naver-Client-Id": "y75cFyztfRqWH6MqHjz4",
    "X-Naver-Client-Secret": "QtZOXTb6DB",
}

now = datetime.now()
now_date_time=now.strftime('%Y-%m-%d, %H:%M:%S')

no = 1
for w in keywords:
    params = {"query":w, "display":"100"}
    r = requests.get(url, headers=headers, params=params)

    data = r.json()
    # print(data)
    for item in data['items']:
        
        title = re.sub('<.*?>', '', item['title'])
        category1 = item['category1']
        category2 = item['category2']
        category3 = item['category3']
        lprice = item['lprice']
        brand = item['brand']

        print(no, title, category1, category2, category3, lprice, brand)

        sql = """
            INSERT INTO myshop(no, category1, category2, category3, brand, title, lprice, regdate) 
             values(?,?,?,?,?,?,?,?)
        """
        cursor.execute(sql, (no, category1, category2, category3, brand, title, lprice, now_date_time))
        
        no += 1
# Out:
# 1 듀플렉스 DP-A20F 디지털/가전 계절가전 선풍기 37800 듀플렉스
# 2 신일 선풍기 가정용선풍기 저소음 스탠드 거실선풍기 원룸 30cm 디지털/가전 계절가전 선풍기 49800 신일전자
# 3 미로 바람이지 12인치 듀얼블레이드 무소음 BLDC 선풍기 디지털/가전 계절가전 선풍기 89000 미로
# 4 케어메디 아이오랩 아이브리즈 무소음 BLDC 선풍기 디지털/가전 계절가전 선풍기 86300 아이오랩
# 5 신일선풍기 무소음 BLDC 선풍기 저소음 가정용 [24년형] 디지털/가전 계절가전 선풍기 169000 신일전자
# 6 오아 에어쿨 핸디 미니 냉각 휴대용 선풍기 디지털/가전 계절가전 선풍기 27800 오아
# 7 칙스 디센느 아이스 넥밴드 선풍기 DSF002 디지털/가전 계절가전 선풍기 45900 디센느
# 8 칙스 디센느 아이스 냉각 미니 손선풍기 디지털/가전 계절가전 선풍기 16900 디센느
# 9 아이닉 iSC01 디지털/가전 계절가전 선풍기 148000 아이닉
# 10 와이투에스 트리아이나 TN-TW747 디지털/가전 계절가전 선풍기 109000 트리아이나
# 11 듀플렉스 DPK-55CF 디지털/가전 계절가전 선풍기 38800 듀플렉스
# 12 루메나 FAN STAND 3Z 디지털/가전 계절가전 선풍기 34060 루메나
# 13 선풍기 거실 리모컨 가정용 저소음 디지털/가전 계절가전 선풍기 48900 윈드피아
# 14 하이온 H14 디지털/가전 계절가전 선풍기 13400 하이온
# 15 헤몬 테이블에어 무선 선풍기 디지털/가전 계절가전 선풍기 21900 헤몬
# 16 모야무 천장선풍기 천장 실링팬 조명 실링펜 디지털/가전 계절가전 선풍기 140000
# 17 신일선풍기 저소음 BLDC 스탠드 무소음 가정용 리모컨 3D 입체회전 SIF-WT14DP 디지털/가전 계절가전 선풍기 139000 신일전자
# 18 루메나 FAN PRO JET 디지털/가전 계절가전 선풍기 39900 루메나
# ...

# %%
# mongod 연동

from pymongo import MongoClient

client = MongoClient("mongodb://pyuser:pyuser@43.202.232.9:27017/")
db = client['pyuser']

# 컬렉션 생성
collection = db.naver_shop

# %%
keywords = ["선풍기", "청바지", "수영복", "신발", "여행"]
url = 'https://openapi.naver.com/v1/search/shop.json'
headers = {
    "X-Naver-Client-Id": "y75cFyztfRqWH6MqHjz4",
    "X-Naver-Client-Secret": "QtZOXTb6DB",
}

now = datetime.now()
now_date_time=now.strftime('%Y-%m-%d, %H:%M:%S')

no = 1
for w in keywords:
    params = {"query":w, "display":"100"}
    r = requests.get(url, headers=headers, params=params)

    data = r.json()
    # print(data)
    for item in data['items']:
        
        title = re.sub('<.*?>', '', item['title'])
        category1 = item['category1']
        category2 = item['category2']
        category3 = item['category3']
        lprice = item['lprice']
        brand = item['brand']

        data1 = dict()
        data1['no']=no
        data1['category1']=category1
        data1['category2']=category2
        data1['category3']=category3
        data1['brand']=brand
        data1['title']=title
        data1['lprice']=lprice

        collection.insert_one(data1)
        no += 1

# %%
# 모든 문서 조회
documents = collection.find()
for d in documents:
    print(d)

# %%
# category1 조회
collection.distinct('category1')
# Out:
# ['디지털/가전', '스포츠/레저', '여가/생활편의', '출산/육아', '패션의류', '패션잡화']

# %%
for p in collection.find({'category1':'패션의류'}):
    print(p)
# Out:
# {'_id': ObjectId('6685024826d9e5d1fbec9f16'), 'no': 101, 'category1': '패션의류', 'category2': '여성의류', 'category3': '청바지', 'brand': '이츠미', 'title': '이츠미 3가지기장 -5도씨 아이스 텐셀 여름 밴딩 세미 와이드 일자 스판 데님 키작녀', 'lprice': '22900'}
# {'_id': ObjectId('6685024826d9e5d1fbec9f17'), 'no': 102, 'category1': '패션의류', 'category2': '여성의류', 'category3': '청바지', 'brand': '', 'title': '포레스트핏 텐셀진 1탄 여름 아이스 밴딩 와이드 청바지', 'lprice': '21540'}
# {'_id': ObjectId('6685024826d9e5d1fbec9f18'), 'no': 103, 'category1': '패션의류', 'category2': '여성의류', 'category3': '청바지', 'brand': '', 'title': '와이드 청바지 여름 하이웨스트 와이드데님 팬츠 5부 반바지 블랙진 화이트 버뮤다 P89', 'lprice': '29900'}
# {'_id': ObjectId('6685024826d9e5d1fbec9f19'), 'no': 104, 'category1': '패션의류', 'category2': '여성의류', 'category3': '청바지', 'brand': '', 'title': '(3XL까지/빅사이즈) 5부 하이웨스트 와이드 데님 여자 청 반바지', 'lprice': '19800'}
# ...

# %%
import pandas as pd
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id  no category1 category2 category3 brand  \
# 0  6685024726d9e5d1fbec9eb2   1    디지털/가전      계절가전       선풍기  듀플렉스
# 1  6685024726d9e5d1fbec9eb3   2    디지털/가전      계절가전       선풍기  신일전자
# 2  6685024726d9e5d1fbec9eb4   3    디지털/가전      계절가전       선풍기    미로
# 3  6685024726d9e5d1fbec9eb5   4    디지털/가전      계절가전       선풍기  아이오랩
# 4  6685024726d9e5d1fbec9eb6   5    디지털/가전      계절가전       선풍기  신일전자
#
#                                  title  lprice
# 0                         듀플렉스 DP-A20F   37800
# 1  신일 선풍기 가정용선풍기 저소음 스탠드 거실선풍기 원룸 30cm   49800
# 2     미로 바람이지 12인치 듀얼블레이드 무소음 BLDC 선풍기   89000
# 3         케어메디 아이오랩 아이브리즈 무소음 BLDC 선풍기   86300
# 4    신일선풍기 무소음 BLDC 선풍기 저소음 가정용 [24년형]  169000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        500 non-null    object
#  1   no         500 non-null    int64
#  2   category1  500 non-null    object
#  3   category2  500 non-null    object
#  4   category3  500 non-null    object
#  5   brand      500 non-null    object
#  6   title      500 non-null    object
#  7   lprice     500 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#                no
# count  500.000000
# mean   250.500000
# std    144.481833
# min      1.000000
# 25%    125.750000
# 50%    250.500000
# 75%    375.250000
# max    500.000000
